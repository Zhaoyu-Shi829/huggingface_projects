# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Zhaoyu Shi** : Unemployed, looking for transition from academia to industry, particularly in data science, application/simulation engineer

# %% [markdown]
# *I am interested in Data Science because I like analysis and gain insights from data when everything seems complex and non-intuitive,
# and also my expertise in CFD involves handling large-scale data, so I'm experienced with simulation data. Now I want to explore the broader range of all kinds of data*

# %% [markdown]
# <h3>This is a simple demo of notebook calculation using python</h3>

# %%
import numpy as np
a = 3.0
b = 4.0
z = np.sqrt(a**2 + b**2)
print(z)
# Out:
# 5.0

# %% [markdown]
# ### tasks:
# 1. apply for the cfd position, game position
# 2. ~~finish module 6 in the course~~
# 3. register new course (generative AI)
#
# * watchc hpc youtube courses
# * play kaggle, house price model
# * work on [github repo](https://github.com/Zhaoyu-Shi829/Particles_Clustering_in_Vortex) of phd work

# %% [markdown]
# <div style="text-align: center;">
#     <img src="attachment:b7f0f7bc-b292-4799-a3bf-2038e5204778.png" width="400"/>
#     <p style="text-align: center; font-size: 20px;"><em>AI application in Chemistry</em></p>
# </div>
